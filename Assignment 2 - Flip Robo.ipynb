# %%
from bs4 import BeautifulSoup
import requests
from random import randint
from time import sleep
import numpy as np
import pandas as pd
import lxml

# %% [markdown]
# ## 2. IMDB’s Top rated 100 movies

# %%
movie_name = []
year = []
IMDB_Rating = []

# %%
#pd.set_option('display.max_row',None)

# %%
pages = np.arange(1,100,50)

# %%
for page in pages:
    page = requests.get('https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start="+str(page)+"&ref_=adv_nxt')
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.find_all('div',attrs={'class':"lister-item mode-advanced"})
    sleep(randint(2,8))
    for store in movie_data:
        name = store.h3.a.text
        movie_name.append(name)
        
        year_of_release = store.h3.find('span',class_='lister-item-year text-muted unbold').text
        year.append(year_of_release)
        
        rating=store.find('div',class_='inline-block ratings-imdb-rating').text
        IMDB_Rating.append(rating.replace('\n',''))

# %%
movie_list = pd.DataFrame({'Name':movie_name,'Year_of_Release':year,'IMDB_Rating':IMDB_Rating})
movie_list
# Out:
#                             Name Year_of_Release IMDB_Rating
# 0       The Shawshank Redemption          (1994)         9.3
# 1                  The Godfather          (1972)         9.2
# 2                The Dark Knight          (2008)         9.0
# 3         The Godfather: Part II          (1974)         9.0
# 4                   12 Angry Men          (1957)         9.0
# ..                           ...             ...         ...
# 95            Back to the Future          (1985)         8.5
# 96  Once Upon a Time in the West          (1968)         8.5
# 97                        Psycho          (1960)         8.5
# 98                    Casablanca          (1942)         8.5
# 99                  Modern Times          (1936)         8.5
#
# [100 rows x 3 columns]

# %%
movie_list.to_csv('IMDB 100 Top Rated Movies.csv')

# %% [markdown]
# ## 1. header tags from ‘en.wikipedia.org/wiki/Main_Page’

# %%
header = requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(header.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
header = soup.find_all('span',class_='mw-headline')
header
# Out:
# [<span class="mw-headline" id="From_today's_featured_article">From today's featured article</span>,
#  <span class="mw-headline" id="Did_you_know_...">Did you know ...</span>,
#  <span class="mw-headline" id="In_the_news">In the news</span>,
#  <span class="mw-headline" id="On_this_day">On this day</span>,
#  <span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span>,
#  <span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span>,
#  <span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span>,
#  <span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span>]

# %%
Header = []
for i in header:
    Header.append(i.text.replace('\n',''))
Header
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %% [markdown]
# ### scrap book name, author name, genre and book review of
# any 5 books from ‘www.bookpage.com’

# %%
books = requests.get('https://bookpage.com/reviews')
soup = BeautifulSoup(books.content, 'html.parser')

# %%
book = soup.find_all('h4',class_='italic')
book_name = []
for i in book:
    book_name.append(i.text.replace('\n',''))
book_name
# Out:
# [' ★ Facing the Mountain',
#  'Lucky Girl',
#  ' ★ On Juneteenth',
#  'Pawcasso',
#  'The Most Beautiful Girl in Cuba',
#  'Why Peacocks?',
#  'The Last Thing He Told Me',
#  'The Secret History of Home Economics',
#  'Little and Often',
#  'The Wreckage of My Presence']

# %%
books = pd.DataFrame({'Name':book_name})
books
# Out:
#                                    Name
# 0                 ★ Facing the Mountain
# 1                            Lucky Girl
# 2                       ★ On Juneteenth
# 3                              Pawcasso
# 4       The Most Beautiful Girl in Cuba
# 5                         Why Peacocks?
# 6             The Last Thing He Told Me
# 7  The Secret History of Home Economics
# 8                      Little and Often
# 9           The Wreckage of My Presence

# %%
book = soup.find_all('p',class_='sans bold')
author = []
for i in book:
    author.append(i.text.replace('\n',''))
author
# Out:
# ['Daniel James Brown',
#  'Jamie Pacton',
#  'Annette Gordon-Reed',
#  'Remy Lai',
#  'Chanel Cleeton',
#  'Sean Flynn',
#  'Laura Dave',
#  'Danielle Dreilinger',
#  'Trent Preszler',
#  'Casey Wilson']

# %%
book = soup.find_all('p',class_='genre-links hidden-phone')
genre = []
for i in book:
    genre.append(i.text.replace('\n',''))
genre
# Out:
# ['Nonfiction / History / American History',
#  'YA Fiction / YA',
#  'Nonfiction / History / American History',
#  "Children's / Middle Grade",
#  'Fiction / Historical Fiction',
#  'Nonfiction / Science & Nature / Animals',
#  'Fiction / Family Drama',
#  "Nonfiction / History / Women's History",
#  'Nonfiction / Memoir / Family & Relationships',
#  'Nonfiction / Essays / Humor']

# %%
books = pd.DataFrame({'Name':book_name,'Author Name':author,'Genre':genre})
books
# Out:
#                                    Name          Author Name  \
# 0                 ★ Facing the Mountain   Daniel James Brown
# 1                            Lucky Girl         Jamie Pacton
# 2                       ★ On Juneteenth  Annette Gordon-Reed
# 3                              Pawcasso             Remy Lai
# 4       The Most Beautiful Girl in Cuba       Chanel Cleeton
# 5                         Why Peacocks?           Sean Flynn
# 6             The Last Thing He Told Me           Laura Dave
# 7  The Secret History of Home Economics  Danielle Dreilinger
# 8                      Little and Often       Trent Preszler
# 9           The Wreckage of My Presence         Casey Wilson
#
#                                           Genre
# 0       Nonfiction / History / American History
# 1                               YA Fiction / YA
# 2       Nonfiction / History / American History
# 3                     Children's / Middle Grade
# 4                  Fiction / Historical Fiction
# ...

# %% [markdown]
# #### Unable to fetch the reviews, as unaware of the code structure. Please, let me know how to do it.

# %% [markdown]
# ## www.icc-cricket.com

# %% [markdown]
# #### Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
ratings = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup = BeautifulSoup(ratings.content, 'html.parser')
ICC = soup.find_all('tr',class_='rankings-block__banner')
sleep(randint(2,8))
for store in ICC:
    name = store.find_all('span','u-hide-phablet')
    Team.append(name)

# %%
ICC_Ratings = pd.DataFrame({'Team':Team})
ICC_Ratings
# Out:
#                                                 Team
# 0                                               None
# 1                                      [New Zealand]
# 2                                               None
# 3                                      [New Zealand]
# 4  [[New Zealand], [Australia], [India], [England...
# 5                                    [[New Zealand]]

# %%
ratings = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup = BeautifulSoup(ratings.content, 'html.parser')
name = soup.find_all('span','u-hide-phablet')[:10]
Team_Name = []
for i in name:
    Team_Name.append(i.text.replace('\n',''))
Team_Name
# Out:
# ['New Zealand',
#  'Australia',
#  'India',
#  'England',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %%
maches = soup.find_all('td',class_=['rankings-block__banner--matches','rankings-block__banner--points','table-body__cell u-center-text'])[:20]
Maches = []
for i in maches:
    Maches.append(i.text.replace('\n',''))
Maches
# Out:
# ['17',
#  '2,054',
#  '25',
#  '2,945',
#  '29',
#  '3,344',
#  '27',
#  '3,100',
#  '20',
#  '2,137',
#  '24',
#  '2,323',
#  '24',
#  '2,157',
#  '27',
#  '2,222',
#  '21',
#  '1,652',
#  '17',
#  '1,054']

# %%
rating = soup.find_all('td',class_=['rankings-block__banner--rating u-text-right','table-body__cell u-text-right rating'])[:10]
Rating = []
for i in rating:
    Rating.append(i.text.replace('\n',''))
Rating
# Out:
# ['                            121                            ',
#  '118',
#  '115',
#  '115',
#  '107',
#  '97',
#  '90',
#  '82',
#  '79',
#  '62']

# %%
ICC = pd.DataFrame({'Name':Team_Name, "Rating":Rating})
ICC
# Out:
#            Name                                             Rating
# 0   New Zealand                              121               ...
# 1     Australia                                                118
# 2         India                                                115
# 3       England                                                115
# 4  South Africa                                                107
# 5      Pakistan                                                 97
# 6    Bangladesh                                                 90
# 7   West Indies                                                 82
# 8     Sri Lanka                                                 79
# 9   Afghanistan                                                 62

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36"}

urls = [
"https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting",
"https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling",
"https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting",
"https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling",
]

final_result_file_name = "All Ranking List.csv"
final_column_names = ["Ranking Type", "Position", "Player Name", "Team Name", "Rating", "Career Best Rating", "Crawl URL"]
pd.DataFrame(columns=final_column_names).to_csv(final_result_file_name, sep="\t", index=False, encoding="utf-8")

for url in urls:
    request_object = requests.get(url, headers=headers)
    html_content = request_object.text
    print(request_object.status_code, "->", url)
    soup_object = BeautifulSoup(html_content, "lxml")
    for element in soup_object.select('[class="ranking-pos up"], [class="ranking-pos down"]'):
        element.replace_with(BeautifulSoup("<" + element.name + "></" + element.name + ">", "html.parser"))

    ranking_type = soup_object.select_one(".rankings-block__title-container > h4").text

    result_file_name = ranking_type + ".csv"
    column_names = ["Position", "Player Name", "Team Name", "Rating", "Career Best Rating", "Crawl URL"]
    pd.DataFrame(columns=column_names).to_csv(result_file_name, sep="\t", index=False, encoding="utf-8")

    for element in soup_object.select('table[class="table rankings-table"] tr'):
        if(element.find("th")):
                continue
        data_dict = dict()
        data_dict["Crawl URL"] = url
        data_dict["Ranking Type"] = ranking_type
        if(element.select_one('[class*="position"]')):
                data_dict["Position"] = element.select_one('[class*="position"]').text
        for player_name in (element.select('a[href*="/player-rankings"]')):
                if(player_name.text.strip()):
                        data_dict["Player Name"] = player_name.text
        if(element.select_one('[class^="flag-15"]')):
                data_dict["Team Name"] = element.select_one('[class^="flag-15"]')["class"][-1]
        if(element.select_one('[class$="rating"]')):
                data_dict["Rating"] = element.select_one('[class$="rating"]').text
        if(element.select_one('td.u-hide-phablet')):
                data_dict["Career Best Rating"] = element.select_one('td.u-hide-phablet').text
        for key in data_dict.keys():
                data_dict[key] = re.sub(r"\s+", " ", data_dict[key])
                data_dict[key] = data_dict[key].strip()
        pd.DataFrame([data_dict], columns=column_names).to_csv(result_file_name, sep="\t", index=False, header=False, encoding="utf-8", mode="a")
        pd.DataFrame([data_dict], columns=final_column_names).to_csv(final_result_file_name, sep="\t", index=False, header=False, encoding="utf-8", mode="a")
# Out:
# 200 -> https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting
# 200 -> https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling
# 200 -> https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting
# 200 -> https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling

# %%
MR = pd.read_csv("Men's ODI Batting Rankings.csv")
MR.head()
# Out:
#                                             Position\tPlayer Name\tTeam Name\tRating\tCareer Best Rating\tCrawl URL
# 1\tBabar Azam\tPAK\t865\t865 v South Africa   07/04/2021\thttps://www.icc-cricket.com/ranki...
# 2\tVirat Kohli\tIND\t857\t911 v England       12/07/2018\thttps://www.icc-cricket.com/ranki...
# 3\tRohit Sharma\tIND\t825\t885 v Sri Lanka    06/07/2019\thttps://www.icc-cricket.com/ranki...
# 4\tRoss Taylor\tNZ\t801\t841 v Bangladesh     05/06/2019\thttps://www.icc-cricket.com/ranki...
# 5\tAaron Finch\tAUS\t791\t798 v England       25/06/2019\thttps://www.icc-cricket.com/ranki...

# %%
MR = pd.read_csv("Men's ODI Bowling Rankings.csv")
MR.head()
# Out:
#                                                Position\tPlayer Name\tTeam Name\tRating\tCareer Best Rating\tCrawl URL
# 1\tTrent Boult\tNZ\t737\t770 v West Indies       22/06/2019\thttps://www.icc-cricket.com/ranki...
# 2\tMujeeb Ur Rahman\tAFG\t708\t712 v Ireland     24/01/2021\thttps://www.icc-cricket.com/ranki...
# 3\tMatt Henry\tNZ\t691\t691 v Bangladesh         26/03/2021\thttps://www.icc-cricket.com/ranki...
# 4\tJasprit Bumrah\tIND\t690\t841 v West Indies   01/11/2018\thttps://www.icc-cricket.com/ranki...
# 5\tMehedi Hasan\tBAN\t668\t694 v West Indies     25/01/2021\thttps://www.icc-cricket.com/ranki...

# %%
MR = pd.read_csv("Women's ODI Batting Rankings.csv")
MR.head()
# Out:
#                                                Position\tPlayer Name\tTeam Name\tRating\tCareer Best Rating\tCrawl URL
# 1\tTammy Beaumont\tENG\t765\t765 v New Zealand   28/02/2021\thttps://www.icc-cricket.com/ranki...
# 2\tLizelle Lee\tSA\t758\t773 v India             14/03/2021\thttps://www.icc-cricket.com/ranki...
# 3\tAlyssa Healy\tAUS\t756\t756 v New Zealand     10/04/2021\thttps://www.icc-cricket.com/ranki...
# 4\tStafanie Taylor\tWI\t746\t765 v India         02/03/2012\thttps://www.icc-cricket.com/ranki...
# 5\tMeg Lanning\tAUS\t723\t834 v New Zealand      24/02/2016\thttps://www.icc-cricket.com/ranki...

# %%
MR = pd.read_csv("Women's ODI Bowling Rankings.csv")
MR.head()
# Out:
#                                               Position\tPlayer Name\tTeam Name\tRating\tCareer Best Rating\tCrawl URL
# 1\tJess Jonassen\tAUS\t808\t808 v New Zealand   10/04/2021\thttps://www.icc-cricket.com/ranki...
# 2\tMegan Schutt\tAUS\t762\t766 v West Indies    11/09/2019\thttps://www.icc-cricket.com/ranki...
# 3\tMarizanne Kapp\tSA\t747\t747 v India         17/03/2021\thttps://www.icc-cricket.com/ranki...
# 4\tShabnim Ismail\tSA\t717\t743 v India         07/03/2021\thttps://www.icc-cricket.com/ranki...
# 5\tJhulan Goswami\tIND\t681\t796 v England      28/02/2007\thttps://www.icc-cricket.com/ranki...
